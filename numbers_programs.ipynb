# %%
# check number is prime or not
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

print(is_prime(10)) 
print(is_prime(11))  # Output: True
# Out:
# False
# True

# %%
# check number is palindrome or not
def is_palindrome(n):
    return str(n) == str(n)[::-1]

print(is_palindrome(121))  # Output: True
print(is_palindrome(123))  # Output: False
# Out:
# True
# False

# %%
# check number is cyclic or not
def is_cyclic(n):
    s = str(n)
    n_digits = len(s)

    # # Generate all rotations
    # rotations = []

    # for i in range(n_digits):
    #     rotations.append(s[i:] + s[:i])

    # print(rotations)
    for i in range(1, n_digits + 1):
        result = str(n * i)

        if result not in s + s:
            return False

    return True

print(is_cyclic(142857))
print(is_cyclic(1234321))
# Out:
# ['142857', '428571', '285714', '857142', '571428', '714285']
# True
# ['1234321', '2343211', '3432112', '4321123', '3211234', '2112343', '1123432']
# False
